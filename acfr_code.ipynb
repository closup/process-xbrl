# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 3.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
from pathlib import Path

# %%
ACFR_TEMPLATE_PATH = Path.cwd() / 'static' / 'input_files' / 'ACFR_template.xlsx'

# %%
df = pd.read_excel(ACFR_TEMPLATE_PATH)
df
# Out:
#                    Category  \
# 0            current_assets
# 1            current_assets
# 2            current_assets
# 3            current_assets
# 4            current_assets
# ..                      ...
# 516  noncurrent_liabilities
# 517  noncurrent_liabilities
# 518  noncurrent_liabilities
# 519  noncurrent_liabilities
# 520  noncurrent_liabilities
#
#                                      Label with Spaces  \
# 0                                  Accounts Receivable
# 1                        Accounts Receivable Allowance
# 2                 Accounts Receivable Net Of Allowance
# 3                         Accounts Receivable Unbilled
# 4               Accounts Receivable Unbilled Allowance
# ..                                                 ...
# 516  Self Insurance Liabilities Net Of Current Portion
# 517  Unamortized Premium On Bonds Due In More Than ...
# 518                        Unearned Revenue Noncurrent
# 519  Unlimited Tax Bonds Principal Due In More Than...
# ...

# %%
new_column_names = {
    "XBRL Label (col C) with string 'ModifiedAccrual' appended": "XBRL Label (modified accrual)",
    
}

df.rename(columns=new_column_names, inplace=True)
